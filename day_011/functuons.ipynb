# %% [markdown]
# # 💻 Exercises: Day 11
#
# ### Exercises: Level 1

# %%
# 1. Declare a function _add_two_numbers_. It takes two parameters and it returns a sum.
def _add_two_numbers(x, y):
    return x + y
print('1. ',_add_two_numbers(3, 5))
# 2. Area of a circle is calculated as follows: area = π x r x r. Write a function that calculates _area_of_circle_.
def circle_area(r):
    π = 3.14
    return  π * r * r
print('2. Area of circle:', circle_area(3))
# 3. Write a function called add_all_nums which takes arbitrary number of arguments and sums all the arguments. Check if all the list items are number types. If not do give a reasonable feedback.
def add_all_nums(*nums):
    sum = 0
    for num in nums:
        sum += num
    return sum
print('3. Sum of all numbers:', add_all_nums(3, 5, 6, 43), type(sum))

# 4. Temperature in °C can be converted to °F using this formula: °F = (°C x 9/5) + 32. Write a function which converts °C to °F, _convert_celsius_to-fahrenheit_.
def celsius_to_fahrenheit(c):
    F = (c* 9/5) + 32
    return F
print('4. Celsius to Fahrenheir:', celsius_to_fahrenheit(30),'°F')
      
# 5. Write a function called check-season, it takes a month parameter and returns the season: Autumn, Winter, Spring or Summer.
def check_season(month):
    month = month.lower()
    if month == 'march' or month == 'april' or month == 'may':
        print('5. we are in Spring season')
    elif month == 'june' or month == 'july' or month == 'august':
        print('5. We are in Summer serson')
    elif month == 'september' or month == 'october' or month == 'november':
        print('5. We are in Autumn serson')
    elif month == 'december' or month == 'january' or month == 'february':
        print('5. We are in Winter serson')
    else:
        print('No month march')
 
print(check_season('February'))


# 6. Write a function called calculate_slope which return the slope of a linear equation
def calculate_slope(x1, x2, y1, y2):
    slope = (y2 -y1)/(x2-x1)
    return slope
print('6. The Slope is: ', calculate_slope(1,2,3,4))
# 7. Quadratic equation is calculated as follows: ax² + bx + c = 0. Write a function which calculates solution set of a quadratic equation, _solve_quadratic_eqn_.
def solve_quadratic_eqn(a, b, c):
    import math
    discriminant = b**2 - 4*a*c

    if discriminant > 0:
        root1 = (-b + math.sqrt(discriminant)) / (2*a)
        root2 = (-b - math.sqrt(discriminant)) / (2*a)
        return root1, root2
    elif discriminant == 0:
        root = -b / (2*a)
        return root,
    else:
        return "No real roots"
print('7.', solve_quadratic_eqn(2,20,4))
# 8. Declare a function named print_list. It takes a list as a parameter and it prints out each element of the list.
def print_list(lst):
    for element in lst:
        print(element)
print('8', [1,2,5,4,'fgsdfg'])
# 9. Declare a function named reverse_list. It takes an array as a parameter and it returns the reverse of the array (use loops).
def reverse_list(arr):
    reversed_arr = []
    for i in range(len(arr) - 1, -1, -1):
        reversed_arr.append(arr[i])
    return reversed_arr
print('9. ', reverse_list([1,2,3,4]))

# 10. Declare a function named capitalize_list_items. It takes a list as a parameter and it returns a capitalized list of items
def capitalize_list_items(lst):
    capitalized_list = [item.capitalize() for item in lst]
    return capitalized_list
print('10', capitalize_list_items(["apple", "banana", "cherry"]))
# 11. Declare a function named add_item. It takes a list and an item parameters. It returns a list with the item added at the end.
def add_item(lst, item):
    lst.append(item)
    return lst
print('11. ', add_item([1,2,3,4], 'naz'))

#12. Declare a function named remove_item. It takes a list and an item parameters. It returns a list with the item removed from 
def remove_item(lst, item):
    lst.remove(item)
    return lst
print('12.', remove_item([1,2,3,'ffrg', 'xaz', 4, 5], 4))

# 13. Declare a function named sum_of_numbers. It takes a number parameter and it adds all the numbers in that range.
def sum_of_numbers(num):
    return sum(range(1, num + 1))

# Example usage:
print('13', sum_of_numbers(5))   

# 14. Declare a function named sum_of_odds. It takes a number parameter and it adds all the odd numbers in that range.
def sum_of_odds(num):
    return sum(x for x in range(1, num + 1) if x % 2 != 0)
print('14,', sum_of_odds(5))

# 15. Declare a function named sum_of_even. It takes a number parameter and it adds all the even numbers in that - range.
def sum_of_evens(num):
    return sum(x for x in range(1, num + 1) if x % 2 == 0)
print('15,', sum_of_evens(5))
# Out:
# 1.  8
# 2. Area of circle: 28.259999999999998
# 3. Sum of all numbers: 57 <class 'builtin_function_or_method'>
# 4. Celsius to Fahrenheir: 86.0 °F
# 5. We are in Winter serson
# None
# 6. The Slope is:  1.0
# 7. (-0.2041684766872809, -9.79583152331272)
# 8 [1, 2, 5, 4, 'fgsdfg']
# 9.  [4, 3, 2, 1]
# 10 ['Apple', 'Banana', 'Cherry']
# 11.  [1, 2, 3, 4, 'naz']
# 12. [1, 2, 3, 'ffrg', 'xaz', 5]
# 13 15
# 14, 9
# 15, 6

# %% [markdown]
# ### Exercises: level 2

# %%
import statistics
# 1. Declare a function named evens_and_odds . It takes a positive integer as parameter and it counts number of evens and odds in the number.
def count_even_odd(limit):
    even_count = 0
    odd_count = 0

    for num in range(1, limit + 1):
        if num % 2 == 0:
            even_count += 1
        else:
            odd_count += 1

    return even_count, odd_count

# Count even and odd numbers up to 100
even, odd = count_even_odd(10)

print(f"The number of even numbers up to 100 is: {even}")
print(f"The number of odd numbers up to 100 is: {odd}")


# 2. Call your function factorial, it takes a whole number as a parameter and it return a factorial of the number
def factorial(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

# 3. Call your function is_empty, it takes a parameter and it checks if it is empty or not
def is_empty(param):
    return not bool(param)

# 4. Write different functions which take lists. They should calculate_mean, calculate_median, calculate_mode, calculate_range, calculate_variance, calculate_std (standard deviation).
def calculate_mean(lst):
    return statistics.mean(lst)

def calculate_median(lst):
    return statistics.median(lst)

def calculate_mode(lst):
    return statistics.mode(lst)

def calculate_range(lst):
    return max(lst) - min(lst)

def calculate_variance(lst):
    return statistics.variance(lst)

def calculate_std(lst):
    return statistics.stdev(lst)

print('2.', factorial(5)) 
print('3.', is_empty([]))  
print('4:')
numbers = [2, 4, 4, 4, 5, 5, 7, 9]
print('Mean:', calculate_mean(numbers)) 
print('Medium:', calculate_median(numbers)) 
print('Mode:', calculate_mode(numbers)) 
print('Range:', calculate_range(numbers)) 
print('Variance:', calculate_variance(numbers))  
print('std:', calculate_std(numbers))
# Out:
# The number of even numbers up to 100 is: 5
# The number of odd numbers up to 100 is: 5
# 2. 120
# 3. True
# 4:
# Mean: 5
# Medium: 4.5
# Mode: 4
# Range: 7
# Variance: 4.571428571428571
# std: 2.138089935299395

# %% [markdown]
# ### Exercises: level 3

# %%
import re
# 1. Write a function called is_prime, which checks if a number is prime.
def is_prime(num):
    if num <= 1:
        return False
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            return False
    return True
print('1.', is_prime(17))
print('1.', is_prime(15))

# 2. Write a functions which checks if all items are unique in the list.
def are_all_unique(lst):
    return len(lst) == len(set(lst))
numbers = [1, 2, 3, 4, 5]
print('2.', are_all_unique(numbers))

# 3. Write a function which checks if all the items of the list are of the same data type.
def are_all_same_type(lst):
    return all(isinstance(elem, type(lst[0])) for elem in lst)

data_types = [1, 2, 3, 'four', 'five']
print('3.', are_all_same_type(data_types)) 

# 4. Write a function which check if provided variable is a valid python variable
def is_valid_variable(variable):
    return re.match(r'^[a-zA-Z_]\w*$', variable) is not None

variable_name = 'valid_variable'
print('4.', is_valid_variable(variable_name))

invalid_variable = '123invalid'
print('4.', is_valid_variable(invalid_variable))
# Out:
# 1. True
# 1. False
# 2. True
# 3. False
# 4. True
# 4. False

# %%
# 5. Go to the data folder and access the countries-data.py file.
# -Create a function called the most_spoken_languages in the world. It should return 10 or 20 most spoken languages in the world in descending order
# -Create a function called the most_populated_countries. It should return 10 or 20 most populated countries in descending order.

import countries_data
countries_data = countries_data.countries_data
# print(countries_data[45])

# Function to get the most spoken languages in the world
def most_spoken_languages(limit=10):
    language_count = {}
    
    for country in countries_data:
        languages = country['languages']
        for language in languages:
            if language in language_count:
                language_count[language] += 1
            else:
                language_count[language] = 1
    
    # Sort the languages by count in descending order
    sorted_languages = sorted(language_count.items(), key=lambda x: x[1], reverse=True)
    
    # Return the top 'limit' most spoken languages
    return sorted_languages[:limit]

# Function to get the most populated countries
def most_populated_countries(limit=10):
    countries_population = {}
    
    for country in countries_data:
        name = country['name']
        population = country['population']
        countries_population[name] = population
    
    # Sort the countries by population in descending order
    sorted_countries = sorted(countries_population.items(), key=lambda x: x[1], reverse=True)
    
    # Return the top 'limit' most populated countries
    return sorted_countries[:limit]

# Example usage:
print('20 Nost spoken languages:', most_spoken_languages(20))  # Get the top 10 most spoken languages
print('10 Most populated countries:', most_populated_countries(10))  # Get the top 10 most populated countries
# Out:
# 20 Nost spoken languages: [('English', 91), ('French', 45), ('Arabic', 25), ('Spanish', 24), ('Portuguese', 9), ('Russian', 9), ('Dutch', 8), ('German', 7), ('Chinese', 5), ('Serbian', 4), ('Swahili', 4), ('Italian', 4), ('Swedish', 3), ('Albanian', 3), ('Croatian', 3), ('Norwegian', 3), ('Uzbek', 2), ('Turkmen', 2), ('Samoan', 2), ('Guaraní', 2)]
# 10 Most populated countries: [('China', 1377422166), ('India', 1295210000), ('United States of America', 323947000), ('Indonesia', 258705000), ('Brazil', 206135893), ('Pakistan', 194125062), ('Nigeria', 186988000), ('Bangladesh', 161006790), ('Russian Federation', 146599183), ('Japan', 126960000)]
