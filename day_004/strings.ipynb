# %% [markdown]
# # Exercises - Day 4
# #### Question 1 to 20

# %%
# 1. Concatenate the string 'Thirty', 'Days', 'Of', 'Python' to a single string, 'Thirty Days Of Python'.
thirty, days, of, python = 'Thirty', 'Days', 'Of', 'Python'
print('1. '+thirty + ' ' + days + ' ' + of + ' ' + python)

# 2. Concatenate the string 'Coding', 'For' , 'All' to a single string, 'Coding For All'.
coding, For, all = 'Coding', 'For' , 'All'
print('2 '+coding + ' ' + For + ' ' + all)


# 3. Declare a variable named company and assign it to an initial value "Coding For All".
company = "Coding For All"

# 4. Print the variable company using _print()_
print('3, 4. '+company)

# 5. Print the length of the company string using _len()_ method and _print()_.
print('5. Length is', len(company))

# 6. Change all the characters to uppercase letters using _upper()_ method.
print('6. ',company.upper())

# 7. Change all the characters to lowercase letters using _lower()_ method.
print('7. ',company.lower())

# 8. Use capitalize(), title(), swapcase() methods to format the value of the string _Coding For All_.
challenge = 'Coding For All'
print('8: ')
print('i. capitalised form is', challenge.capitalize())
print('ii. title form is', challenge.title())
print('iii. swapcased form is', challenge.swapcase())

# 9. Cut(slice) out the first word of _Coding For All_ string.
print('9. first word is', challenge[:6])

# 10. Check if _Coding For All_ string contains a word Coding using the method index, find or other methods.
print('10. is Coding there in \'Coding For All\'', 'Coding' in challenge)

# 11. Replace the word coding in the string 'Coding For All' to Python.
print('11. ', challenge.replace('Coding', 'Python'))

# 12. Change Python for Everyone to Python for All using the replace method or other methods.
python_for_everybody = 'Python for Everybody'
print('12. ', python_for_everybody.replace('Everybody', 'All') )

# 13. Split the string 'Coding For All' using space as the separator (split()) .
print('13. ', challenge.split(" "))

# 14. "Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon" split the string at the comma.
facebook = "Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon"
print('14. ', facebook.split(','))

# 15. What is the character at index 0 in the string _Coding For All_.
print('15. ', challenge[0])

# 16. What is the last index of the string _Coding For All_.
print('16. ', challenge[-1])

# 17. What character is at index 10 in "Coding For All" string.
print('17. ', challenge[10])

# 18. Create an acronym or an abbreviation for the name 'Python For Everyone'.
# Original phrase1
phrase1 = 'Python For Everyone'

# Split the phrase1 into words1
words1 = phrase1.split()

# Extract the initial letters from each word
acronym = ''.join(word[0].upper() for word in words1)

print("18. The acronym for 'Python For Everyone' is:", acronym)


# 19. Create an acronym or an abbreviation for the name 'Coding For All'.
# Original phrase2
phrase2 = 'Coding For All'

# Split the phrase2 into words2
words2 = phrase2.split()

# Extract the initial letters from each word
acronym = ''.join(word[0].upper() for word in words2)

print(f"19. The acronym for 'Python For Everyone' is: {acronym}")


# 20. Use index to determine the position of the first occurrence of C in Coding For All.
sub_string = 'C'
print('20. ', challenge.index(sub_string))
# Out:
# 1. Thirty Days Of Python
# 2 Coding For All
# 3, 4. Coding For All
# 5. Length is 14
# 6.  CODING FOR ALL
# 7.  coding for all
# 8:
# i. capitalised form is Coding for all
# ii. title form is Coding For All
# iii. swapcased form is cODING fOR aLL
# 9. first word is Coding
# 10. is Coding there in 'Coding For All' True
# 11.  Python For All
# 12.  Python for All
# 13.  ['Coding', 'For', 'All']
# 14.  ['Facebook', ' Google', ' Microsoft', ' Apple', ' IBM', ' Oracle', ' Amazon']
# 15.  C
# 16.  l
# 17.
# 18. The acronym for 'Python For Everyone' is: PFE
# 19. The acronym for 'Python For Everyone' is: CFA
# 20.  0

# %% [markdown]
# #### Question 21 to 36

# %%
challenge = 'Coding For All'
# 21. Use index to determine the position of the first occurrence of F in Coding For All.
print('21. ', challenge.index('F'))

# 22. Use rfind to determine the position of the last occurrence of l in Coding For All People.
print('22. ', challenge.index('l'))

# 23. Use index or find to find the position of the first occurrence of the word 'because' in the following sentence: 'You cannot end a sentence with because because because is a conjunction'
phrase = 'You cannot end a sentence with because because because is a conjunction'
print('23. ', phrase.find('because'))

# 24. Use rindex to find the position of the last occurrence of the word because in the following sentence: 'You cannot end a sentence with because because because is a conjunction'
print('24. ', phrase.rindex('because'))

# 25. Slice out the phrase 'because because because' in the following sentence: 'You cannot end a sentence with because because because is a conjunction'
print('25. ', phrase[31:54])
# 
# 26. Find the position of the first occurrence of the word 'because' in the following sentence: 'You cannot end a sentence with because because because is a conjunction'
print('26. ', phrase.index('because'))
# 
# 27. Slice out the phrase 'because because because' in the following sentence: 'You cannot end a sentence with because because because is a conjunction'
print('27. ', phrase[31:54])
# 
# 28. Does '\'Coding For All' start with a substring _Coding_?
print('28. ', challenge.startswith('Coding'))

# 29. Does 'Coding For All' end with a substring _coding_?
print('29. ', challenge.endswith('coding'))
# 30.  Coding For All      '  , remove the left and right trailing spaces in the given string.
# Original string
given_string = '   Coding For All      '

# Removing leading and trailing spaces
trimmed_string = given_string.strip()

# Displaying the trimmed string
print('30.', trimmed_string)

# 31. Which one of the following variables return True when we use the method isidentifier():
print('31: ')
challenge = '30DaysOfPython'
print('30DaysOfPython is not valid variablr name:', challenge.isidentifier())
challenge = 'thirty_days_of_python'
print('thirty_days_of_python is valid variable name:', challenge.isidentifier())
# 32. The following list contains the names of some of python libraries: ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']. Join the list with a hash with space string.
given_list = ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']
print('32. ', '# '.join(given_list))
# 33. Use the new line escape sequence to separate the following sentences.
print('33:')
print('I am enjoying this challenge.\n') 
print('I just wonder what is next.')
# 34. Use a tab escape sequence to write the following lines.
print('34:')
print('Name\t2 Age\t5 Country\t3 City')
print('Asabeneh\t2 250\t5     Finland\t3 Helsinki')

# 35. Use the string formatting method to display the following:
print('35. ')
radius = 10
area = 3.14 * radius ** 2
print(f'radius = {radius}')
print(f'area = 3.14 * radius ** 2')
print(f'The area of a circle with radius {radius} is {area} meters square.')

# 36. Make the following using string formatting methods:
print('36:')
x = 8
y = 6
print(f'x + y = {x+y}')
print(f'x - y = {x-y}')
print(f'x * y = {x*y}')
print(f'x / y = {x/y}')
print(f'x % y = {x%y}')
print(f'x // y = {x//y}')
print(f'x ** y = {x**y}')
# Out:
# 21.  7
# 22.  12
# 23.  31
# 24.  47
# 25.  because because because
# 26.  31
# 27.  because because because
# 28.  True
# 29.  False
# 30. Coding For All
# 31:
# 30DaysOfPython is not valid variablr name: False
# thirty_days_of_python is valid variable name: True
# 32.  Django# Flask# Bottle# Pyramid# Falcon
# 33:
# I am enjoying this challenge.
#
# I just wonder what is next.
# 34:
# Name	2 Age	5 Country	3 City
# Asabeneh	2 250	5     Finland	3 Helsinki
# 35.
# radius = 10
# area = 3.14 * radius ** 2
# The area of a circle with radius 10 is 314.0 meters square.
# 36:
# x + y = 14
# x - y = 2
# x * y = 48
# x / y = 1.3333333333333333
# x % y = 2
# x // y = 1
# x ** y = 262144
